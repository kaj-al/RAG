# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
cache = {}

llm = ChatOpenAI(model="openai/gpt-4o",api_key= os.getenv("OPENAI_API_KEY"), base_url="https://openrouter.ai/api/v1", max_tokens=1000)

# %%
def chat(query):
    if query in cache:
        print("\n" +"Response from cache")
        return cache[query]
    print("\n" + "New response")
    response = llm.invoke([HumanMessage(content = query)])
    ans = response.content
    cache[query] = ans

    return ans

# %%
while True:
    query = input("Ask something")
    if  query.lower() == 'exit':
        break
    result = chat(query)
    print(result)
